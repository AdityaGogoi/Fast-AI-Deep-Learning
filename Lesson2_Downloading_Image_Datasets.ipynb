# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaGogoi/Fast-AI-Deep-Learning/blob/master/Lesson2_Downloading_Image_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ad blocking extensions (uBlock, AdBlockPlus etc.) in Chrome. Otherwise window.open() coomand doesn't work. Then you can run the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
folder = 'black'
file = 'urls_black.csv'

# %%
folder = 'teddys'
file = 'urls_teddys.csv'

# %%
folder = 'grizzly'
file = 'urls_grizzly.csv'

# %%
# Mounting Google Drive instead of Local Drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# You will need to run this cell once per each category.

# %%
# Changing stuff to point to Google Drive and create folders there.
path = Path(base_dir + 'data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_grizzly.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_teddys.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_black.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/black'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/teddys'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/grizzly')]

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](https://github.com/fastai/course-v3/blob/master/nbs/dl1/images/download_images/upload.png?raw=1)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['teddys','grizzly','black']

# %%
download_images(path/file, dest, max_pics=200)

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
download_images(path/file, dest, max_pics=20, max_workers=0)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 443, 110)

# %% [markdown]
# ## Train model

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:00<00:00, 160120943.36it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.873036</td>
#       <td>0.255666</td>
#       <td>0.081818</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.502896</td>
#       <td>0.286302</td>
#       <td>0.072727</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.360097</td>
#       <td>0.288117</td>
#       <td>0.072727</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.282591</td>
#       <td>0.259746</td>
#       <td>0.063636</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# If the plot is not showing try to give a start and end learning rate
# Plot is not showing, so using this command 
learn.lr_find(start_lr=1e-5, end_lr=1e-1)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.079840</td>
#       <td>0.335378</td>
#       <td>0.063636</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.070887</td>
#       <td>0.368066</td>
#       <td>0.063636</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

# db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
#                    .no_split()
#                    .label_from_df()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
# Don't run this in google colab or any other instances running jupyter lab.# If you do run this on Jupyter Lab, you need to restart your runtime and# runtime state including all local variables will be lost.ImageCleaner(ds, idxs, path)
# Out:
# 'No images to show :)'

# %% [markdown]
# If the code above does not show any GUI(contains images and buttons) rendered by widgets but only text output, that may caused by the configuration problem of ipywidgets. Try the solution in this [link](https://github.com/fastai/fastai/issues/1539#issuecomment-505999861) to solve it.

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %% [markdown]
# Make sure to recreate the databunch and `learn_cln` from the `cleaned.csv` file. Otherwise the file would be overwritten from scratch, loosing all the results from cleaning the data from toplosses.

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='9', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9/9 00:05<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# 'No images to show :)'

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000188.jpg')
img
# Out:
# Image (3, 365, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>15.340745</td>
#       <td>461967872.000000</td>
#       <td>0.609091</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.436877</td>
#       <td>1.401200</td>
#       <td>0.827273</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.489865</td>
#       <td>1.252158</td>
#       <td>0.718182</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.442047</td>
#       <td>1.180665</td>
#       <td>0.636364</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.422936</td>
#       <td>1.147885</td>
#       <td>0.600000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.411245</td>
#       <td>1.154089</td>
#       <td>0.590909</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.973963</td>
#       <td>1.723585</td>
#       <td>0.700000</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 91900926.27it/s]

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.044880</td>
#       <td>1.228438</td>
#       <td>0.766600</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.013137</td>
#       <td>1.207179</td>
#       <td>0.750503</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.999070</td>
#       <td>1.181389</td>
#       <td>0.710262</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.006513</td>
#       <td>1.145601</td>
#       <td>0.670020</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.971582</td>
#       <td>1.107644</td>
#       <td>0.623742</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# Even though the above cell shows that the **Error Rate** is consistently decreasing, there is **definitely** a chance of **Overfitting**, where the Error Rate decrease at first, but then starts increasing with increase in number of epochs.

# %% [markdown]
# ## Adding more bears to the dataset
# For my exercise, I will use the same technique to add 2 more bear species to the dataset:
# 1. Polar bear
# 2. Pandas
#
# Then I will use a standard Resnet-34 to run a CNN on all of the dataset to classify 5 bear species (1 being Teddy bears, of course).

# %% [markdown]
# For the first portion of my data collection I have already downloaded the URLs CSV file from Google Images using the JavaScript snippet provided for Pandas and Polar bears, and added the CSV files to the Drive folder.
#
# Rather than re-using the code snippets for file creation and downloading, I will write seperate codes for pandas and polar bears.

# %%
folder = 'panda'
file = 'urls_panda.csv'

# %%
# The Google Drive has already been mounted before, so will not run this cell again
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'

# %%
path = Path(base_dir + 'data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_grizzly.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_teddys.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_black.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/black'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/teddys'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/grizzly'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/models'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/export.pkl'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_polar.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_panda.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/panda')]

# %%
download_images(path/file, dest, max_pics=200)

# %% [markdown]
# Now that I have downloaded panda images, I will now proceed with Polar bear images.

# %%
folder = 'polar'
file = 'urls_polar.csv'

# %%
path = Path(base_dir + 'data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_grizzly.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_teddys.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_black.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/black'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/teddys'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/grizzly'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/models'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/export.pkl'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_polar.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/urls_panda.csv'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/panda'),
#  PosixPath('/content/gdrive/My Drive/fastai-v3/data/bears/polar')]

# %%
download_images(path/file, dest, max_pics=200)

# %% [markdown]
# With all the images downloaded, I will define all the **classes** and try to **remove** the images that **cannot be opened**.

# %%
classes = ['teddys','grizzly','black', 'polar', 'panda']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %% [markdown]
# With the faulty images deleted and classes defined, we can now create a **DataBunch object** with all the classes.
#
#
# From the DataBunch object, we will see:
#
# 1. **Number of classes** in the DataBunch
# 2. **Sample data-points** along with its class.
# 3. See how the **train and validation dataset** has been split.

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'panda', 'polar', 'teddys']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'panda', 'polar', 'teddys'], 5, 746, 186)

# %% [markdown]
# After creating the **ImageDataBunch** object, we can train a standard **CNN Learner** with **Resnet-34** weights and train it within **4 epochs**.

# %%
learn2 = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn2.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.276423</td>
#       <td>0.218825</td>
#       <td>0.053763</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.695646</td>
#       <td>0.191019</td>
#       <td>0.043011</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.467174</td>
#       <td>0.193991</td>
#       <td>0.053763</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.348536</td>
#       <td>0.192348</td>
#       <td>0.048387</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now that we have a model with decent **error-rate** (4% - 5%), we can save this model and try to find its most optimum **Learning-Rate** (LR).
#
# The **lr_find** along with its **recorder.plot** will give us a good estimate to limit its LR and make it more accurate.

# %%
learn2.save('stage-4')

# %%
learn2.unfreeze()

# %%
learn2.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn2.recorder.plot()

# %% [markdown]
# We can see from the plot that the most drop in **Loss** happens between the **LR** of **1e-05 to 1e-04**.
#
# So, we will train the model once again but this time we will **limit the LR** to these limits and see if it has any difference.

# %%
learn2.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.143654</td>
#       <td>0.187102</td>
#       <td>0.037634</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.105946</td>
#       <td>0.192529</td>
#       <td>0.032258</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see quite an improvement in the **Error Rate** where it has reduced to almost 3%.
#
# We will first save this model version and then use it to create a **Confusion Matrix**.

# %%
learn2.save('stage-5')

# %%
learn2.load('stage-5');

# %%
interp = ClassificationInterpretation.from_learner(learn2)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# We see a really accurate Confusion Matrix where there are very few misclassifications. The worst case is between Grizzly and Black which is actually very low and the mistake is understandable under some conditions.
#
# I cannot use the widgets as I am using Colab and not doing this locally, so I will avoid all the Dataset cleanup portions. I will also not repeat the Mistakes portion as it is for learning purposes only.
#
# What I will do is pick up a random, new image of each species of bear from Google images and use the model to classify them.

# %% [markdown]
# First, we will **export our model** and then **switch** our de-facto device from **GPU to CPU**.

# %%
learn2.export()

# %%
defaults.device = torch.device('cpu')

# %% [markdown]
# I have picked **random** images of **each bear species** from Google and added it to the respective Drive folder.
#
# We will use the latest version of the model and verify if its predictions are correct or not.

# %%
img = open_image(path/'panda'/'00009999.jpeg')
img
# Out:
# Image (3, 183, 275)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category panda

# %%
img = open_image(path/'black'/'00009999.jpeg')
img
# Out:
# Image (3, 165, 306)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category black

# %%
img = open_image(path/'polar'/'00009999.jpeg')
img
# Out:
# Image (3, 183, 275)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category polar

# %%
img = open_image(path/'grizzly'/'00009999.jpeg')
img
# Out:
# Image (3, 261, 193)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category grizzly

# %%
img = open_image(path/'teddys'/'00009999.jpeg')
img
# Out:
# Image (3, 225, 225)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category teddys

# %% [markdown]
# The model is giving **very accurate** results.
#
# But lets consider a scenario in which the image is **not** of any species that the model has been trained on.
#
# For this we will use the **Red-panda**, an endangered species and a **distant relative** to the **giant panda** (whose images have been used to train the model).
#
# We will add the images of red-panda in various different folders and use the model to predict which species the model thinks it belongs to.

# %%
img = open_image(path/'panda'/'00009998.jpeg')
img
# Out:
# Image (3, 168, 300)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category panda

# %%
img = open_image(path/'black'/'00009998.jpeg')
img
# Out:
# Image (3, 168, 300)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category panda

# %%
img = open_image(path/'grizzly'/'00009997.jpeg')
img
# Out:
# Image (3, 183, 275)

# %%
pred_class,pred_idx,outputs = learn2.predict(img)
pred_class
# Out:
# Category panda

# %% [markdown]
# We can see in each case the model **classifies** the image as a **panda**, which is eerie as the **red-panda** is actually **related** to the giant **pandas**.
#
# What might be leading the model to this conclusion is the **distinct pattern around the eyes** of the red-panda, which is also a **trait shared** by the giant pandas.
#
# This proves that for **sub-species** that have **common visual traits**, **CNN** can be a great way to classify them together.

# %% [markdown]
# ### Conclusion
#
# 1. I have learned how to use the **download_images** function in Fast AI along with a simple **Javascript code-snippet** and **Google Images** to get any image dataset as long as it can be found in Google.
#
# 2. Fast AI also has a **widget library** that allows **manual removal** of images based on how much loss they incurred in a training cycle.
#
# 3. I also took a case-study of using CNN to **classify** different sub-species images into the **same group** through **common visual traits** between them
